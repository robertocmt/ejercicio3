# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class Comercios:
    def base(self):
        global df
        df = pd.read_csv("comercios.csv")

# %%
bd = Comercios()
bd.base()
print(df)
# Out:
#      Comercio Producto  Precio   Provincia  Renta
# 0   Mercadona    Pasta    0.75     Almeria   1000
# 1   Mercadona    Leche    0.59     Granada    900
# 2   Mercadona      Pan    0.71        Jaen   1100
# 3        Lidl    Pasta    0.62     Cordoba    950
# 4        Lidl      Pan    0.50      Malaga   1100
# 5        Lidl    Leche    0.80     Sevilla   1500
# 6   Carrefour    Pasta    0.55       Cadiz   1300
# 7   Carrefour      Pan    0.87      Huelva    900
# 8   Carrefour    Leche    0.25      Murcia   1000
# 9         Dia    Pasta    1.20     Badajoz    800
# 10        Dia      Pan    0.34     Caceres    800
# 11        Dia    Leche    0.48    Albacete   1100
# 12   Hipercor    Pasta    1.25     Vizcaya   1300
# 13   Hipercor      Pan    0.90      Madrid   1400
# 14   Hipercor    Leche    1.25   Barcelona   1500
# 15     Consum    Pasta    0.58    Valencia   1200
# 16     Consum      Pan    0.22  Valladolid    950
# 17     Consum    Leche    0.54        Leon   1000

# %%
df.groupby(['Comercio','Producto'])['Precio'].min().plot(kind='bar')

# %%
df.groupby('Provincia')['Renta'].max().plot(kind='bar')
